# %%
'''String handling in Python
As we know that str is immutable data type and it cant perform slicing and indexing operations
But the pre-defined functions in str data type perform these operations'''

# %%
'''1.capitalize()'''
s="python is object-oriented"
s=s.capitalize()
print(s)
# Out:
# Python is object-oriented

# %%
s="python"
s=s.capitalize()
print(s)
# Out:
# Python

# %%
x="javascript"
print(x.capitalize())
# Out:
# Javascript

# %%
'''2.title()'''
v="python is dynamically-typed"
print(v.title())
# Out:
# Python Is Dynamically-Typed

# %%
x="largest of all @'s"
print(x.title())
# Out:
# Largest Of All @'S

# %%
c="python3.12"
print(c.title())
# Out:
# Python3.12

# %%
'''3.swapcase()'''
x="python"
print(x.swapcase())
# Out:
# PYTHON

# %%
x="python3.18"
print(x.swapcase())
# Out:
# PYTHON3.18

# %%
x="PYthoN Is a ProgRAMMING Lang"
x=x.swapcase()
print(x)
# Out:
# pyTHOn iS A pROGramming lANG

# %%
'''4.upper()'''
x="Jython"
print(x.upper())
# Out:
# JYTHON

# %%
x="golang3.9"
print(x.upper())
# Out:
# GOLANG3.9

# %%
b="kotlin is also a new programming lang"
print(b.upper())
# Out:
# KOTLIN IS ALSO A NEW PROGRAMMING LANG

# %%
'''5.lower()'''
x="Meerut plays a lot"
print(x.lower())
# Out:
# meerut plays a lot

# %%
k="99@5G"
print(k.lower())
# Out:
# 99@5g

# %%
n="DO you KNow me?"
n=n.lower()
print(n)
# Out:
# do you know me?

# %%
'''6.isupper()'''
x="python"
print(x.isupper())
# Out:
# False

# %%
x="python3.12 is platform-independent"
print(x.isupper())
# Out:
# False

# %%
x="JAVA"
print(x.isupper())
# Out:
# True

# %%
'''7.islower()'''
x="laravel is a well-known trader"
print(x.islower())
# Out:
# True

# %%
x="OAKLAND IS IN USA"
print(x.islower())
# Out:
# False

# %%
x="python is freeware for every 24 hours"
print(x.islower())
# Out:
# True

# %%
'''8.isalpha()'''
x="p997yth"
print(x.isalpha())
# Out:
# False

# %%
k="matter bolo bhaya!"
print(k.isalpha())
# Out:
# False

# %%
k="I know that"
print(k.isalpha())
# Out:
# False

# %%
x="lorelum ipsum"
print(x.isalpha())
# Out:
# False

# %%
x1="Cranberry"
print(x1.isalpha())
# Out:
# True

# %%
'''9.isalnum()'''
x="python312"
print(x.isalnum())
# Out:
# True

# %%
b="magie@99"
print(b.isalnum())
# Out:
# False

# %%
x="python"
print(x.isalnum())
# Out:
# True

# %%
x="123"
print(x.isalnum())
# Out:
# True

# %%
x="123.45" 
print(x.isalnum())
# Out:
# False

# %%
'''10.isdecimal()'''
x="mommy 3.14"
print(x.isdecimal())
# Out:
# False

# %%
x="123.456"
print(x.isdecimal())
# Out:
# False

# %%
x="9"
print(x.isdecimal())
# Out:
# True

# %%
'''11.strip()'''
s="   Harshitha  "
print(s.strip())
# Out:
# Harshitha

# %%
len(s)
# Out:
# 14

# %%
place=" mysore "
print(place.strip())
# Out:
# mysore

# %%
len(place.strip())
# Out:
# 6

# %%
lang="##python##"
print(lang.strip("#"))
# Out:
# python

# %%
'''12.lstrip()'''
s="    python3.24   "
print(s.lstrip())
# Out:
# python3.24

# %%
print(len(s.lstrip()))
# Out:
# 13

# %%
'''13.rstrip()'''
s="   markdown   "
print(s.rstrip())
print(len(s.rstrip()))
# Out:
#    markdown
# 11

# %%
'''14.join()'''
x="python   is   a  extended  &  embedded"
print(''.join(x.split()))
# Out:
# pythonisaextended&embedded

# %%
'''15.split()'''
x="Mary is wife of John"
print(x.split())
# Out:
# ['Mary', 'is', 'wife', 'of', 'John']

# %%
x=" 1  4  8"
print(x.split())
# Out:
# ['1', '4', '8']

# %%
x=" @  %  ^  *  (  ) #"
print(x.split())
# Out:
# ['@', '%', '^', '*', '(', ')', '#']

# %%
'''16.replace()'''
x="Carefree"
print(x.replace("free", "ful"))
# Out:
# Careful

# %%
x="990 byte"
print(x.replace("990", "222"))
# Out:
# 222 byte

# %%
'''17.casefold()'''
x="HIIII"
print(x.casefold())
# Out:
# hiiii

# %%
for index,value in enumerate(x):
    print(index,value)
# Out:
# 0 H
# 1 I
# 2 I
# 3 I
# 4 I
