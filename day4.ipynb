# %%
#datatypes in python
a=10
print(a)
print(a,type(a))
a=10.5
print(a)
print(a,type(a))
a=True
print(a,type(a))
a=10+5j
print(a)
print(a,type(a))
a="KVSH"
print(a,type(a))
# Out:
# 10
# 10 <class 'int'>
# 10.5
# 10.5 <class 'float'>
# True <class 'bool'>
# (10+5j)
# (10+5j) <class 'complex'>
# KVSH <class 'str'>

# %%
#base conversions in python
#case1:
a=0b1011 # binary 
print(a,type(a))
a=0x1011 # hexadecimal
print(a,type(a))
a=0o1110 # octal
print(a,type(a))
# Out:
# 11 <class 'int'>
# 4113 <class 'int'>
# 584 <class 'int'>

# %%
#case2:
bin(14)
bin(20)
bin(300)
# Out:
# '0b100101100'

# %%
hex(14)
hex(20)
hex(300)
# Out:
# '0x12c'

# %%
oct(14)
oct(20)
oct(300)
# Out:
# '0o454'

# %%
a=0o17
bin(a)
print(a,type(a))
# Out:
# 15 <class 'int'>

# %%
a=0b10000
oct(a)
print(a,type(a))
# Out:
# 16 <class 'int'>

# %%
a=0b0011010
hex(a)
print(a,type(a))
# Out:
# 26 <class 'int'>

# %%
#float conversions
a=3e2 #mantisa e Exponent 
print(a,type(a))
# Out:
# 300.0 <class 'float'>

# %%
a=0.0000000000000000000000000000000000004
print(a,type(a))
# Out:
# 4e-37 <class 'float'>

# %%
a=0b10110.0b10
print(a,type(a))
# Out:
#   Cell In[54], line 1
#     a=0b10110.0b10
#               ^
# SyntaxError: invalid decimal literal

# %%
#bool conversions
a=True
print(a,type(a))
# Out:
# True <class 'bool'>

# %%
a=True
b=False
c=a+b
print(c,type(c))
print(True+False)
# Out:
# 1 <class 'int'>
# 1

# %%
a=3+7j
print(a,type(a))
print(a.real)
print(a.imag)
# Out:
# (3+7j) <class 'complex'>
# 3.0
# 7.0

# %%
a=9.7+6.5j
print(a,type(a))
print(a.real)
print(a.imag)
# Out:
# (9.7+6.5j) <class 'complex'>
# 9.7
# 6.5

# %%
#sequence category data types
s1="python"
print(s1,type(s1))
s2='123456789'
print(s2,type(s2))
# Out:
# python <class 'str'>
# 123456789 <class 'str'>

# %%
s1="""Python Programming Language"""
print(s1,type(s1))
# Out:
# Python Programming Language <class 'str'>

# %%
#memory management of str data:
#1.indexing in forward direction
s="PYTHON"
print(s[0])
s[2]
s[5]
# Out:
# P
# 'N'

# %%
#2.indexing in backward direction
s="PYTHON"
print(s[-1])
s[-6]
s[-10]
# Out:
# N
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[77], line 5
#       3 print(s[-1])
#       4 s[-6]
# ----> 5 s[-10]
#
# IndexError: string index out of range

# %%
#slicing operations
#syntax1: strobj[beginindex:endindex]
s="PYTHON"
s[0:3]
# Out:
# 'THO'

# %%
s[1:-4]
# Out:
# 'Y'

# %%
s[-5:0]
# Out:
# ''

# %%
"HYDERABAD"[-122:0]
# Out:
# ''

# %%
#syntax 2: strobj[beginindex:]
s="PYTHON"
s[4:]
# Out:
# 'PYTHON'

# %%
s[-122:]
# Out:
# 'PYTHON'

# %%
s[True:False]
# Out:
# ''

# %%
s[False:True]
# Out:
# 'P'

# %%
#syntax3: strobj[endindex:]
s="PYTHON" 
s[:2]
# Out:
# 'PY'

# %%
s[:6]
# Out:
# 'PYTHON'

# %%
s[:0]
# Out:
# ''

# %%
s[:-1]
# Out:
# 'PYTHO'

# %%
s[:-0]
# Out:
# ''

# %%
#syntax4: strobj[:]
s="PYTHON"
s[:]
# Out:
# 'PYTHON'

# %%
s[-122:989]
#NOTE: ALL THE ABOVE SYNTAXES ARE GIVING RANGE OF VALUES (SUBSTRINGS) IN FORWARD DIRECTION WITH DEFAULT STEP +1
# Out:
# 'PYTHON'

# %%
#syntax5:strobj[begin:end:step] 
s="PYTHON"
s[::1]
# Out:
# 'PYTHON'

# %%
s[::]
# Out:
# 'PYTHON'

# %%
s[0:6:2]
# Out:
# 'PTO'

# %%
s[-6:-2:4]
# Out:
# 'P'

# %%
s[0::2]
# Out:
# 'PTO'

# %%
s[:-122:1]
# Out:
# ''

# %%
s="LIRIL"
s==s[::-1]
# Out:
# True

# %%
#type casting techniques in python
#1.int()
#syntax:varname(float/bool/complex/str)
#1.a) float type into int type----POSSIBLE
a=12.34
print(a,type(a))
b=int(a)
print(b,type(b))
# Out:
# 12.34 <class 'float'>
# 12 <class 'int'>

# %%
'''1.a) bool type into int type-------POSSIBLE'''
a=True
print(a,type(a))
b=int(a)
print(b,type(b))
# Out:
# True <class 'bool'>
# 1 <class 'int'>

# %%
'''1.c) complex type into int type-------NOT POSSIBLE'''
a=2+6j
print(a,type(a))
b=int(a)
print(b,type(b))
# Out:
# (2+6j) <class 'complex'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 4
#       2 a=2+6j
#       3 print(a,type(a))
# ----> 4 b=int(a)
#       5 print(b,type(b))
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
'''1.d) str type into int type-------POSSIBLE'''
a="123"
print(a,type(a))
b=int(a)
print(b,type(b))
# Out:
# 123 <class 'str'>
# 123 <class 'int'>

# %%
"""4.1  pure str type into int type----- NOT POSSIBLE"""
a="KVSRKVSR"
print(a,type(a))
b=int(a)
print(b,type(b))
# Out:
# KVSRKVSR <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 4
#       2 a="KVSRKVSR"
#       3 print(a,type(a))
# ----> 4 b=int(a)
#       5 print(b,type(b))
#
# ValueError: invalid literal for int() with base 10: 'KVSRKVSR'

# %%
'''4.2 str int type into int type-------POSSIBLE'''
a="406"
print(a,type(a))
b=int(a)
print(b,type(b))
# Out:
# 406 <class 'str'>
# 406 <class 'int'>

# %%
'''4.3 str float type into int type----NOT POSSIBLE'''
a="123.45"
print(a,type(a))
b=int(a)
print(b,type(b))
# Out:
# 123.45 <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 4
#       2 a="123.45"
#       3 print(a,type(a))
# ----> 4 b=int(a)
#       5 print(b,type(b))
#
# ValueError: invalid literal for int() with base 10: '123.45'

# %%
'''4.4 str bool type into int type---NOT POSSIBLE'''
a="True"
print(a,type(a))
b=int(a)
print(b,type(b))
# Out:
# True <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 4
#       2 a="True"
#       3 print(a,type(a))
# ----> 4 b=int(a)
#       5 print(b,type(b))
#
# ValueError: invalid literal for int() with base 10: 'True'

# %%
'''4.5 str complex type into int type-------NOT POSSIBLE'''
a="3+7j"
print(a,type(a))
b=int(a)
# Out:
# 3+7j <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 4
#       2 a="3+7j"
#       3 print(a,type(a))
# ----> 4 b=int(a)
#
# ValueError: invalid literal for int() with base 10: '3+7j'

# %%
'''2.float()
syntax:varname=float(str/bool/complex/int)'''
#2.a) int type into float type-------POSSIBLE
a=15
print(a,type(a))
b=float(a)
print(b,type(b))
# Out:
# 15 <class 'int'>
# 15.0 <class 'float'>

# %%
'''2.b) bool type into float type-------POSSIBLE'''
a=True
print(a,type(a))
b=float(a)
print(b,type(b))
# Out:
# True <class 'bool'>
# 1.0 <class 'float'>

# %%
'''2.c) complex type into float type-------NOT POSSIBLE'''
a=2+6j
print(a,type(a))
b=float(a)
print(b,type(b))
# Out:
# (2+6j) <class 'complex'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 a=2+6j
#       3 print(a,type(a))
# ----> 4 b=float(a)
#       5 print(b,type(b))
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
'''2.d) str type to float type-------POSSIBLE'''
a="100"
print(a,type(a))
b=float(a)
print(b,type(b))
# Out:
# 100 <class 'str'>
# 100.0 <class 'float'>

# %%
'''case1: pure str type into float type-------NOT POSSIBLE'''
p="allonerello"
print(p,type(p))
q=float(p)
print(q,type(q))
# Out:
# allonerello <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 4
#       2 p="allonerello"
#       3 print(p,type(p))
# ----> 4 q=float(p)
#       5 print(q,type(q))
#
# ValueError: could not convert string to float: 'allonerello'

# %%
'''case 2: str int type into  float type-------POSSIBLE'''
a="15"
print(a,type(a))
b=float(a)
print(b,type(b))
# Out:
# 15 <class 'str'>
# 15.0 <class 'float'>

# %%
'''case 3: str float type into float type-------POSSIBLE'''
a="15.5"
print(a,type(a))
b=float(a)
print(b,type(b))
# Out:
# 15.5 <class 'str'>
# 15.5 <class 'float'>

# %%
'''case 4: str bool type into float type-------NOT POSSIBLE'''
a="True"
print(a,type(a))
b=float(a)
print(b,type(b))
# Out:
# True <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 4
#       2 a="True"
#       3 print(a,type(a))
# ----> 4 b=float(a)
#       5 print(b,type(b))
#
# ValueError: could not convert string to float: 'True'

# %%
'''case 5. str complex type into float type-------NOT POSSIBLE'''
a=5+2j
print(a,type(a))
b=float(a)
print(b,type(b))
# Out:
# (5+2j) <class 'complex'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       2 a=5+2j
#       3 print(a,type(a))
# ----> 4 b=float(a)
#       5 print(b,type(b))
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
'''3.bool()'''
#eg 1: bool type to int type-------POSSIBLE
a=True
print(a,type(a))
b=int(a)
print(b,type(b))
# Out:
# True <class 'bool'>
# 1 <class 'int'>

# %%
#eg 2: bool type into float type-------POSSIBLE
p=True
print(p,type(p))
q=float(q)
print(q,type(q))
# Out:
# True <class 'bool'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       2 p=True
#       3 print(p,type(p))
# ----> 4 q=float(q)
#       5 print(q,type(q))
#
# NameError: name 'q' is not defined

# %%
#eg 3: bool type into complex type-------POSSIBLE
a=True
print(a,type(a))
b=complex(a)
print(b,type(b))
# Out:
# True <class 'bool'>
# (1+0j) <class 'complex'>

# %%
#eg 4:bool type into str type-------POSSIBLE
i=True
print(i,type(i))
j=str(i)
print(j,type(j))
# Out:
# True <class 'bool'>
# True <class 'str'>

# %%
'''case1: str int type into bool type-------POSSIBLE'''
a="18"
print(a,type(a))
b=int(a)
print(b,type(b))
# Out:
# 18 <class 'str'>
# 18 <class 'int'>

# %%
'''case2: str float type into bool type-------POSSIBLE'''
a="18.5"
print(a,type(a))
b=float(a)
print(b,type(b))
# Out:
# 18.5 <class 'str'>
# 18.5 <class 'float'>

# %%
'''case 3: str bool type into bool type-------POSSIBLE'''
a="True"
print(a,type(a))
b=bool(a)
print(b,type(b))
# Out:
# True <class 'str'>
# True <class 'bool'>

# %%
'''case 4: str complex into bool type-------POSSIBLE'''
a="8+6j"
print(a,type(a))
b=complex(a)
print(b,type(b))
# Out:
# 8+6j <class 'str'>
# (8+6j) <class 'complex'>

# %%
'''case 5: pure str type into bool type----POSSIBLE'''
a="hello"
print(a,type(a))
b=bool(a)
print(b,type(b))
# Out:
# hello <class 'str'>
# True <class 'bool'>

# %%
'''complex()
syntax varname=complex(int/float/str/bool)'''
#4.a) int type into complex type
a=9
print(a,type(a))
b=complex(a)
print(b,type(b))
# Out:
# 9 <class 'int'>
# (9+0j) <class 'complex'>

# %%
#4.b) float type into complextype-------POSSIBLE
a=9.8
print(a,type(a))
b=complex(b)
print(b,type(b))
# Out:
# 9.8 <class 'float'>
# (9+0j) <class 'complex'>

# %%
#4.c) bool type intocomplex type---------POSSIBLE
a=True
print(a,type(a))
b=complex(a)
print(b,type(b))
# Out:
# True <class 'bool'>
# (1+0j) <class 'complex'>

# %%
#4.d) bool type into str type-------POSSIBLE
a=True
print(a,type(a))
b=str(a)
print(b,type(b))
# Out:
# True <class 'bool'>
# True <class 'str'>

# %%
'''str  type into complex type-------POSSIBLE'''
a="3+7j"
print(a,type(a))
b=complex(a)
print(b,complex(b))
# Out:
# 3+7j <class 'str'>
# (3+7j) (3+7j)

# %%
'''str  float type into complex type-------POSSIBLE'''
a="3.99"
print(a,type(a))
b=complex(a)
print(b,type(b))
# Out:
# 3.99 <class 'str'>
# (3.99+0j) <class 'complex'>

# %%
''' str bool type into complex type-------POSSIBLE'''
a="true"
print(a,type(a))
b=complex(a)
print(b,type(b))
# Out:
# true <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 4
#       2 a="true"
#       3 print(a,type(a))
# ----> 4 b=complex(a)
#       5 print(b,type(b))
#
# ValueError: complex() arg is a malformed string

# %%
'''str complex type into complex type------- NOT POSSIBLE'''
a="4+8j"
print(a,type(a))
b=complex(a)
print(b,type(b))
# Out:
# 4+8j <class 'str'>
# (4+8j) <class 'complex'>

# %%
''' pure str type into complex type------NOT POSSIble'''
a="viren"
print(a,type(a))
b=complex(a)
print(b,type(b))
# Out:
# viren <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 4
#       2 a="viren"
#       3 print(a,type(a))
# ----> 4 b=complex(a)
#       5 print(b,type(b))
#
# ValueError: complex() arg is a malformed string
