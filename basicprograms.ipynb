# %%
class Greeter:
    def say_hello(self):
        print("Hello , World!")
g=Greeter()
g.say_hello()
# Out:
# Hello , World!

# %%
name=input("enter your name:")
print(f"Hello , World!")
# Out:
# Hello , World!

# %%
import sys
print("Hello," , sys.argv[1] if len(sys.argv)>1 else "World!")
# Out:
# Hello, --f=c:\Users\hello\AppData\Roaming\jupyter\runtime\kernel-v392c0939d88a26e152ac79b3e1a263d8bd55f05f1.json

# %%
import logging
logging.basicConfig(level=logging.INFO)
logging.info("Hello,World!")
# Out:
# INFO:root:Hello,World!

# %%
import logging
logging.basicConfig(level=logging.INFO)
logging.info("Sai Harshitha")
# Out:
# INFO:root:Sai Harshitha

# %%
class Welcome:
    def self_intro(self):
        print("Hi I am KVSH")
w=Welcome()
w.self_intro()
# Out:
# Hi I am KVSH

# %%
class Calculator:
    def add(self,x,y):
        return x+y
    def subtract(self,x,y):
        return x-y
    def multiply(self,x,y):
        return x*y
    def divide(self,x,y):
        return x/y
calc=Calculator()    
a=float(input("enter first number:"))
b=float(input("enter second number:"))
print("Addition:", calc.add(a,b))
print("Subtraction:",calc.subtract(a,b))
print("Multiplication:",calc.multiply(a,b))
print("Division:",calc.divide(a,b))
# Out:
# Addition: 7.0
# Subtraction: 3.0
# Multiplication: 10.0
# Division: 2.5

# %%
#arithmetic operations on division
num1=float(input("enter the dividend for division"))
num2=float(input("enter the divisor for division:"))
if num2==0:
    print("error, Division by zero is not allowed:")
else:
    div_result=num1/num2
    print(f"Division: {num1}/{num2}={div_result}")
# Out:
# Division: 10.0/5.0=2.0

# %%
#area of triangle
base=int(input("enter the length of the base of the area of the triangle:") )
height=int(input("enter the height of the traiangle:"))
area=0.5*base*height
print(f"area of the triangle is:{area}")
# Out:
# area of the triangle is:1541.0

# %%
#Swapping two variables
a=input("enter the value of the first variable (a):")
b=input("enter the value of the second variable:(b)")
print(f"Original values are:a={a},b={b}")
temp=a
a=b
b=temp
print(f"Swapped values are:a={a},b={b}")
# Out:
# Original values are:a=4,b=6
# Swapped values are:a=6,b=4
