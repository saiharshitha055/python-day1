# %%
'''relational operators features'''
'''>,<,==,!=,>=,<='''
'''note1:complex datatypes cant be compared with relational operators bcoz complex number is the composition of numerical values with special symbol 'j'''
"india"=="INDIA"
# Out:
# False

# %%
"india"=="india"
# Out:
# True

# %%
"abc"=="acb"
# Out:
# False

# %%
"abc"=="ABC"
# Out:
# False

# %%
"wrong"=="wrogn"
# Out:
# False

# %%
for i in range(65,91):
    print(i,"==>",chr(i))
# Out:
# 65 ==> A
# 66 ==> B
# 67 ==> C
# 68 ==> D
# 69 ==> E
# 70 ==> F
# 71 ==> G
# 72 ==> H
# 73 ==> I
# 74 ==> J
# 75 ==> K
# 76 ==> L
# 77 ==> M
# 78 ==> N
# 79 ==> O
# 80 ==> P
# 81 ==> Q
# 82 ==> R
# 83 ==> S
# 84 ==> T
# 85 ==> U
# 86 ==> V
# 87 ==> W
# 88 ==> X
# 89 ==> Y
# 90 ==> Z

# %%
'''to find unicode value of any symbol or alphabet,we use ord()'''
ord('p')
# Out:
# 112

# %%
ord("P")
# Out:
# 80

# %%
ord("$")
# Out:
# 36

# %%
ord("?")
# Out:
# 63

# %%
'''chr() is used for obtaining char value for numerical integer values'''
chr(111)
# Out:
# 'o'

# %%
chr(38)
# Out:
# '&'

# %%
chr(55)
# Out:
# '7'

# %%
'''logical operators
the purpose of these operators is to combine two or more relational expressions
if two or more relational expressions are combined with each other they are called logical operators '''
#1.and operator:
'''the functionality of and operation is described as:
 false and true----> false
 true and false---->false
 true and true---->true
 false and false----->false'''

# %%
10>20 and 20>10
# Out:
# False

# %%
20>10 and 40>20
# Out:
# True

# %%
'''short circuit evaluation of and operator:if two or more relational expressions connected with 'and' operator and if the result of first r.e is false then PVM will not evaluate sub-sequent r.e's'''
10>20 and 20>30 and 10>4
# Out:
# False

# %%
10>2 and 30>20 and 10>2
# Out:
# True

# %%
'''or operator: the functionality of or operator is described as follows:
false and true ---->True
false and false----> false
true and false---->true
true and true----> true'''
'''short circuit evaluation of or operator:if two or more relational operators connected with or aand if the result of first relational expression is true then PVM will not evaluate second and third r.e's and considered as true'''

# %%
10>2 or 20>30
# Out:
# True

# %%
20>30 and 10>2
# Out:
# False

# %%
20>30 and 10>30
# Out:
# False

# %%
10>2 and 20>4
# Out:
# True

# %%
'''3.not operator:the functionality of not operator is described as 
not true--->false
not false--->true'''
not 123   
'''as we know that all non-zero values or operators are treated as true'''
# Out:
# False

# %%
not -2345
# Out:
# False

# %%
not 000
# Out:
# True

# %%
'''special points on "and" operator'''
100 and 200
# Out:
# 200

# %%
100 and 0
# Out:
# 0

# %%
-24 and -35
# Out:
# -35

# %%
100 and 10 and 1
# Out:
# 1

# %%
100 and True and -25
# Out:
# -25

# %%
'python' and 'java' and 'c++'
# Out:
# 'c++'

# %%
True and True and 'python'
# Out:
# 'python'

# %%
'''special points on "or" operator'''
100 or 200
# Out:
# 100

# %%
100 or 0
# Out:
# 100

# %%
0 or 100
# Out:
# 100

# %%
0 or 100 or 'Python'
# Out:
# 100

# %%
100 or 200 or 300
# Out:
# 100

# %%
'''special points of 'not' operator'''
not 123
# Out:
# False

# %%
not False
# Out:
# True

# %%
not 0
# Out:
# True

# %%
not (10-10)
# Out:
# True

# %%
not "20"
# Out:
# False

# %%
not "null"
# Out:
# False

# %%
'''special points on "and","or" and "not" operators'''
100 or 200 and 300 or 400
# Out:
# 100

# %%
10 and 20 or 40 and 50 or 40 and 80
# Out:
# 20

# %%
"python" and "java" and "HTML" or "Django" and 20
# Out:
# 'HTML'

# %%
0 and 30 or -123 and 0 and "python" or True
# Out:
# True
